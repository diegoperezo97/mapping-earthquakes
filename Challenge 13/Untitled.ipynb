# %%
import requests
import json

# %%
json = requests.get("https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson").json()

# %%
for i in json["features"]:
    print(i)
# Out:
# {'type': 'Feature', 'properties': {'mag': 1.4, 'place': '41 km NNW of Valdez, Alaska', 'time': 1651338553063, 'updated': 1651338747042, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0225iqnyzu', 'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0225iqnyzu.geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'automatic', 'tsunami': 0, 'sig': 30, 'net': 'ak', 'code': '0225iqnyzu', 'ids': ',ak0225iqnyzu,', 'sources': ',ak,', 'types': ',origin,phase-data,', 'nst': None, 'dmin': None, 'rms': 0.79, 'gap': None, 'magType': 'ml', 'type': 'earthquake', 'title': 'M 1.4 - 41 km NNW of Valdez, Alaska'}, 'geometry': {'type': 'Point', 'coordinates': [-146.5481, 61.4862, 29.4]}, 'id': 'ak0225iqnyzu'}
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-57402c9bdce9> in <module>
# ----> 1 colombia = [re.search("[Colombia]", the_string) for i in json["features"][i]["place"]]
#
# NameError: name 'i' is not defined
